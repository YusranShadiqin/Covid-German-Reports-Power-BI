# %%
import pandas as pd

# %%
data1 = pd.read_csv("covid_de.csv")

# %%
data1.head(100)
# Out:
#                  state              county age_group gender        date  \
# 0   Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-03-27
# 1   Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-03-28
# 2   Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-04-03
# 3   Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-10-18
# 4   Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2020-10-22
# ..                 ...                 ...       ...    ...         ...
# 95  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2021-10-25
# 96  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2021-10-27
# 97  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2021-11-01
# 98  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2021-11-03
# 99  Baden-Wuerttemberg  LK Alb-Donau-Kreis     00-04      F  2021-11-04
#
#     cases  deaths  recovered
# 0       1       0          1
# 1       1       0          1
# ...

# %%
data1.tail(100)
# Out:
#               state     county age_group gender        date  cases  deaths  \
# 2684378  Thueringen  SK Weimar     80-99      M  2022-05-02      3       0
# 2684379  Thueringen  SK Weimar     80-99      M  2022-05-04      1       0
# 2684380  Thueringen  SK Weimar     80-99      M  2022-05-05      1       0
# 2684381  Thueringen  SK Weimar     80-99      M  2022-05-09      1       0
# 2684382  Thueringen  SK Weimar     80-99      M  2022-05-10      1       0
# ...             ...        ...       ...    ...         ...    ...     ...
# 2684473  Thueringen  SK Weimar       NaN      F  2021-12-23      1       0
# 2684474  Thueringen  SK Weimar       NaN      F  2022-08-11      1       0
# 2684475  Thueringen  SK Weimar       NaN      F  2022-09-19      1       0
# 2684476  Thueringen  SK Weimar       NaN      F  2022-10-03      1       0
# 2684477  Thueringen  SK Weimar       NaN    NaN  2022-08-24      1       0
#
#          recovered
# 2684378          3
# 2684379          1
# ...

# %%
data1.isnull().sum()
# Out:
# state             0
# county            0
# age_group     14001
# gender       122409
# date              0
# cases             0
# deaths            0
# recovered         0
# dtype: int64

# %%
data1.dropna(subset = 'age_group', inplace = True)

# %%
data1.isnull().sum()
# Out:
# state             0
# county            0
# age_group         0
# gender       121173
# date              0
# cases             0
# deaths            0
# recovered         0
# dtype: int64

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
data1.to_csv("covid_de_clean.csv", index = False)

# %%
data1['age_group'].unique()
# Out:
# array(['00-04', '05-14', '15-34', '35-59', '60-79', '80-99', nan],
#       dtype=object)

# %%
data1.columns
# Out:
# Index(['state', 'county', 'age_group', 'gender', 'date', 'cases', 'deaths',
#        'recovered'],
#       dtype='object')

# %%
data2 = pd.read_csv("covid_de_vaccines.csv")

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 692 non-null    object
#  1   doses                692 non-null    int64
#  2   doses_first          692 non-null    int64
#  3   doses_second         692 non-null    int64
#  4   pfizer_cumul         692 non-null    int64
#  5   moderna_cumul        692 non-null    int64
#  6   astrazeneca_cumul    692 non-null    int64
#  7   persons_first_cumul  692 non-null    int64
#  8   persons_full_cumul   692 non-null    int64
# dtypes: int64(8), object(1)
# memory usage: 48.8+ KB

# %%
data2.head(100)
# Out:
#           date   doses  doses_first  doses_second  pfizer_cumul  \
# 0   2020-12-27   24421        24421             0         24412
# 1   2020-12-28   18007        18007             0         42417
# 2   2020-12-29   50055        50055             0         92471
# 3   2020-12-30   64066        64066             0        156536
# 4   2020-12-31   49939        49939             0        206473
# ..         ...     ...          ...           ...           ...
# 95  2021-04-01  332389       241487         90902      10684846
# 96  2021-04-02  226449       158464         67985      10864750
# 97  2021-04-03  232485       167799         64686      11038937
# 98  2021-04-04  193508       142940         50568      11171558
# 99  2021-04-05  248523       178085         70438      11337155
#
#     moderna_cumul  astrazeneca_cumul  persons_first_cumul  persons_full_cumul
# 0               8                  1                24421                   0
# ...

# %%
data2.isnull().sum()
# Out:
# date                   0
# doses                  0
# doses_first            0
# doses_second           0
# pfizer_cumul           0
# moderna_cumul          0
# astrazeneca_cumul      0
# persons_first_cumul    0
# persons_full_cumul     0
# dtype: int64

# %%
data2.duplicated().sum()
# Out:
# 0

# %%
data2['date'] = pd.to_datetime(data2['date'])

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 692 non-null    datetime64[ns]
#  1   doses                692 non-null    int64
#  2   doses_first          692 non-null    int64
#  3   doses_second         692 non-null    int64
#  4   pfizer_cumul         692 non-null    int64
#  5   moderna_cumul        692 non-null    int64
#  6   astrazeneca_cumul    692 non-null    int64
#  7   persons_first_cumul  692 non-null    int64
#  8   persons_full_cumul   692 non-null    int64
# dtypes: datetime64[ns](1), int64(8)
# memory usage: 48.8 KB

# %%
data3 = pd.read_csv("demographics_de.csv")

# %%
data3.head(100)
# Out:
#                      state  gender age_group  population
# 0       Baden-Wuerttemberg  female     00-04      261674
# 1       Baden-Wuerttemberg  female     05-14      490822
# 2       Baden-Wuerttemberg  female     15-34     1293488
# 3       Baden-Wuerttemberg  female     35-59     1919649
# 4       Baden-Wuerttemberg  female     60-79     1182736
# ..                     ...     ...       ...         ...
# 95  Mecklenburg-Vorpommern    male     80-99       42614
# 96           Niedersachsen  female     00-04      180313
# 97           Niedersachsen  female     05-14      349011
# 98           Niedersachsen  female     15-34      875509
# 99           Niedersachsen  female     35-59     1392647
#
# [100 rows x 4 columns]

# %%
data3.tail(100)
# Out:
#                       state  gender age_group  population
# 92   Mecklenburg-Vorpommern    male     15-34      160846
# 93   Mecklenburg-Vorpommern    male     35-59      291204
# 94   Mecklenburg-Vorpommern    male     60-79      194352
# 95   Mecklenburg-Vorpommern    male     80-99       42614
# 96            Niedersachsen  female     00-04      180313
# ..                      ...     ...       ...         ...
# 187              Thueringen    male     05-14       92545
# 188              Thueringen    male     15-34      214553
# 189              Thueringen    male     35-59      384822
# 190              Thueringen    male     60-79      264189
# 191              Thueringen    male     80-99       57340
#
# [100 rows x 4 columns]

# %%
data3.isnull().sum()
# Out:
# state         0
# gender        0
# age_group     0
# population    0
# dtype: int64

# %%
data3.duplicated().sum()
# Out:
# 0
